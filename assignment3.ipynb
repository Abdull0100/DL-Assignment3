# %% [markdown]
# Name: Abdullah Tahir\
# CMS: 385714\
# Section: B

# %%
import pandas as pd
#reading our dataset into a dataframe
df = pd.read_csv('urdu-sentiment-corpus-v1.tsv', delimiter='\t')
df
# Out:
#                                                  Tweet Class
# 0    میں نے ایٹم بم بنایا ھے ۔۔۔۔او بھائی ایٹم بمب ...     P
# 1    چندے سے انقلاب اور عمران خان وزیر اعظم نہیں بن...     N
# 2                             ٹویٹر کا خیال کیسے آیا ؟     O
# 3    سرچ انجن گوگل کے نائب صدر نے فضا میں ، 130,000...     P
# 4      ابھی تک اسکی لہریں کبھی کبھی آ جاتی ہیں یار :أْ     P
# ..                                                 ...   ...
# 995     اُس آدمی نے اِس سالار کو کافی معقول ٹپ دی ہے ۔     P
# 996  چچا غالب کی روح سے معذرت کے ساتھہم نے مانا کہ ...     P
# 997  واہ جناب واہ! اچھی رہی۔ جناب خود کو فرشتہ سمجو...     P
# 998  اسلام آباد :پی اے ٹی کا دھرنا ختم، صفائی کے کا...     P
# 999  دنیا نے کس کا راہ وفا میں دیا ہے ساتھتم بھی چل...     P
#
# [1000 rows x 2 columns]

# %%
#visualizing values for each class
df['Class'].value_counts()
# Out:
# Class
# N    499
# P    480
# O     20
# Name: count, dtype: int64

# %%
#removing examples with insignificant count
df = df.drop(df[df['Class'] == 'O'].index)
df = df.dropna()

# %%
#affirming that the dataset was indeed changed.
df['Class'].value_counts()
# Out:
# Class
# N    499
# P    480
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import nltk
import re
from nltk.tokenize import word_tokenize

nltk.download('punkt')

#cleaning the tweet data
def clean_tweet(tweet):
    #removing common stopwords from urdu in unicode
    cleaned_tweet = re.sub(r"[^\u0600-\u06FF\u0750-\u077F#@ ]", "", tweet)
    return cleaned_tweet

#apply the clean_tweet method to the tweet column of the dataframe to return cleaned tweets
df['Cleaned_Tweet'] = df['Tweet'].apply(clean_tweet)

#tokenizing the cleaned tweets
df['Tokenized'] = df['Cleaned_Tweet'].apply(word_tokenize)

#initializing tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['Tokenized'])

#converting the text to sequences
sequences = tokenizer.texts_to_sequences(df['Tokenized'])

#padding sequences to hav euniform length
max_seq_length = max(len(seq) for seq in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_seq_length, padding='post')

#mapping text labels to numeric values
label_mapping = {'P': 1, 'N': 0}
df['Class'] = df['Class'].map(label_mapping)

#converting class to numeric type after mapping
df['Class'] = df['Class'].astype(int)
#getting labels from the numeric values of the dataframe column
labels = df['Class'].values

#defining train test split
X_train, X_test, y_train, y_test = train_test_split(
    padded_sequences, labels, test_size=0.25, random_state=42
)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
#defining vocab size and embedding size
vocab_size = len(tokenizer.word_index) + 1
embedding_size = 64

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.layers import Dropout


# Create the model
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=64, input_length=max_seq_length))
model.add(LSTM(32,return_sequences=True))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(32)))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.000075), loss='binary_crossentropy', metrics=['accuracy'])

lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.75, patience=5, verbose=1, min_delta=0.0001, cooldown=0, min_lr=0.0)

# Train the model
model.fit(X_train, y_train, epochs=40, validation_split=0.2, callbacks=[lr_scheduler])

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Epoch 1/40
# 19/19 [==============================] - 9s 188ms/step - loss: 0.6932 - accuracy: 0.4991 - val_loss: 0.6936 - val_accuracy: 0.4626 - lr: 7.5000e-05
# Epoch 2/40
# 19/19 [==============================] - 2s 98ms/step - loss: 0.6929 - accuracy: 0.5128 - val_loss: 0.6935 - val_accuracy: 0.4490 - lr: 7.5000e-05
# Epoch 3/40
# 19/19 [==============================] - 2s 77ms/step - loss: 0.6926 - accuracy: 0.5145 - val_loss: 0.6938 - val_accuracy: 0.4558 - lr: 7.5000e-05
# Epoch 4/40
# 19/19 [==============================] - 2s 79ms/step - loss: 0.6925 - accuracy: 0.5128 - val_loss: 0.6939 - val_accuracy: 0.4490 - lr: 7.5000e-05
# Epoch 5/40
# 19/19 [==============================] - 1s 50ms/step - loss: 0.6919 - accuracy: 0.5128 - val_loss: 0.6940 - val_accuracy: 0.4490 - lr: 7.5000e-05
# Epoch 6/40
# 19/19 [==============================] - ETA: 0s - loss: 0.6913 - accuracy: 0

# 19/19 [==============================] - 0s 23ms/step - loss: 0.3277 - accuracy: 0.9608 - val_loss: 0.9284 - val_accuracy: 0.5102 - lr: 3.1641e-05
# Epoch 22/40
# 19/19 [==============================] - 0s 18ms/step - loss: 0.2816 - accuracy: 0.9727 - val_loss: 0.8885 - val_accuracy: 0.4966 - lr: 2.3730e-05
# Epoch 23/40
# 19/19 [==============================] - 0s 19ms/step - loss: 0.2464 - accuracy: 0.9779 - val_loss: 0.9603 - val_accuracy: 0.4966 - lr: 2.3730e-05
# Epoch 24/40
# 19/19 [==============================] - 0s 27ms/step - loss: 0.2201 - accuracy: 0.9796 - val_loss: 0.9960 - val_accuracy: 0.5034 - lr: 2.3730e-05
# Epoch 25/40
# 19/19 [==============================] - 0s 24ms/step - loss: 0.1941 - accuracy: 0.9830 - val_loss: 1.0777 - val_accuracy: 0.4966 - lr: 2.3730e-05
# Epoch 26/40
# 14/19 [=====================>........] - ETA: 0s - loss: 0.1758 - accuracy: 0.9844
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.7797852706280537e-05.
# 19/19 [==============================] - 0s 23ms/step - loss: 0.1797 - accuracy: 0.9796 - val_loss: 1.0369 - val_accuracy: 0.5102 - lr: 2.3730e-05
# Epoch 27/40
# 19/19 [==============================] - 0s 23ms/step - loss: 0.1612 - accuracy: 0.9779 - val_loss: 1.1244 - val_accuracy: 0.4966 - lr: 1.7798e-05
# Epoch 28/40
# 19/19 [==============================] - 1s 28ms/step - loss: 0.1447 - accuracy: 0.9864 - val_loss: 1.1669 - val_accuracy: 0.4966 - lr: 1.7798e-05
# Epoch 29/40
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1416 - accuracy: 0.9796 - val_loss: 1.1573 - val_accuracy: 0.5102 - lr: 1.7798e-05
# Epoch 30/40
# 19/19 [==============================] - 1s 29ms/step - loss: 0.1253 - accuracy: 0.9796 - val_loss: 1.2250 - val_accuracy: 0.5034 - lr: 1.7798e-05
# Epoch 31/40
# 19/19 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9813
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.3348389529710403e-05.
# 19/19 [==============================] - 1s 37ms/step - loss: 0.1174 - accuracy: 0.9813 - val_loss: 1.2177 - val_accuracy: 0.5034 - lr: 1.7798e-05
# Epoch 32/40
# 19/19 [==============================] - 1s 28ms/step - loss: 0.1075 - accuracy: 0.9864 - val_loss: 1.2672 - val_accuracy: 0.5102 - lr: 1.3348e-05
# Epoch 33/40
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1039 - accuracy: 0.9847 - val_loss: 1.2738 - val_accuracy: 0.5034 - lr: 1.3348e-05
# Epoch 34/40
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0979 - accuracy: 0.9847 - val_loss: 1.3261 - val_accuracy: 0.4898 - lr: 1.3348e-05
# Epoch 35/40
# 19/19 [==============================] - 0s 21ms/step - loss: 0.0933 - accuracy: 0.9881 - val_loss: 1.3361 - val_accuracy: 0.4966 - lr: 1.3348e-05
# Epoch 36/40
# 19/19 [==============================] - ETA: 0s - loss: 0.0838 - accuracy: 0.9864
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.0011292488343315e-05.
# 19/19 [==============================] - 0s 20ms/step - loss: 0.0838 - accuracy: 0.9864 - val_loss: 1.3638 - val_accuracy: 0.4898 - lr: 1.3348e-05
# Epoch 37/40
# 19/19 [==============================] - 1s 40ms/step - loss: 0.0843 - accuracy: 0.9864 - val_loss: 1.3642 - val_accuracy: 0.5034 - lr: 1.0011e-05
# Epoch 38/40
# 19/19 [==============================] - 0s 23ms/step - loss: 0.0825 - accuracy: 0.9813 - val_loss: 1.3772 - val_accuracy: 0.5034 - lr: 1.0011e-05
# Epoch 39/40
# 19/19 [==============================] - 0s 18ms/step - loss: 0.0865 - accuracy: 0.9830 - val_loss: 1.3348 - val_accuracy: 0.4830 - lr: 1.0011e-05
# Epoch 40/40
# 19/19 [==============================] - 0s 18ms/step - loss: 0.0807 - accuracy: 0.9847 - val_loss: 1.4112 - val_accuracy: 0.4966 - lr: 1.0011e-05
# 8/8 [==============================] - 0s 5ms/step - loss: 1.0020 - accuracy: 0.6449
# Test Accuracy: 0.6449

# %%
model.save('best_model.keras')
